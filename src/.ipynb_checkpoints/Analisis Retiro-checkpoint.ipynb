# %%
import pandas as pd
import matplotlib as plt
import mplsoccer as mls

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df_lineups = pd.read_excel('../lineups.xlsx', sheet_name='Hoja1')
df_lineups.head()
# Out:
#    id  jersey_number     player_name             team country time_card  \
# 0   0              1   Ignacio Salas  C.D. Retiro Sur   Spain       NaN
# 1   1              3  Manuel Pascual  C.D. Retiro Sur   Spain       NaN
# 2   2              5    Adrian Lopez  C.D. Retiro Sur   Spain     89:00
# 3   3              6  Francisco José  C.D. Retiro Sur   Spain       NaN
# 4   4              7     Juan Camilo  C.D. Retiro Sur   Spain     67:00
#
#   card_type          reason  period  position_id position   from     to  \
# 0       NaN             NaN     NaN            1      POR  00:00    NaN
# 1       NaN             NaN     NaN            2       LD    NaN    NaN
# 2    Yellow  Falta cometida     2.0            3       CB  00:00    NaN
# 3       NaN             NaN     NaN            4       LI  00:00    NaN
# 4    Yellow  Falta cometida     2.0            5       DC  00:00  84:00
#
#    from_period  to_period start_reason end_reason
# 0          1.0        NaN           XI      Final
# 1          NaN        NaN          NaN        NaN
# 2          1.0        NaN           XI      Final
# 3          1.0        NaN           XI      Final
# 4          1.0        2.0           XI    Táctico

# %%
df_events = pd.read_excel('../eventos.xlsx', sheet_name='Hoja1')
df_events.head()
# Out:
#       timestamp                        team          type  minute  x_location  \
# 0  00:00:00.000             C.D. Retiro Sur   Starting XI       0         NaN
# 1  00:00:00.000  Escuela Dep. Moratalaz 'D'   Starting XI       0         NaN
# 2  00:00:00.000  Escuela Dep. Moratalaz 'D'    Half Start       0         NaN
# 3  00:00:00.000             C.D. Retiro Sur    Half Start       0        60.0
# 4  00:00:00.253             C.D. Retiro Sur  Ball Receipt       0        38.0
#
#    y_location  x_pass_end_location  y_pass_end_location pass_recipient  \
# 0         NaN                  NaN                  NaN            NaN
# 1         NaN                  NaN                  NaN            NaN
# 2         NaN                  NaN                  NaN            NaN
# 3        40.0                 34.0                 34.0   Adrian Lopez
# 4        32.0                  NaN                  NaN            NaN
#
#   pass_outcome  pass_height        player  possession_team  shot_aerial_won  \
# 0          NaN          NaN           NaN  C.D. Retiro Sur              NaN
# 1          NaN          NaN           NaN  C.D. Retiro Sur              NaN
# 2          NaN          NaN           NaN  C.D. Retiro Sur              NaN
# 3     Complete  Ground Pass   Ali Nabahim  C.D. Retiro Sur              NaN
# 4          NaN          NaN  Adrian Lopez  C.D. Retiro Sur              NaN
#
#   shot_body_part  x_shot_end_location  y_shot_end_location  \
# 0            NaN                  NaN                  NaN
# 1            NaN                  NaN                  NaN
# 2            NaN                  NaN                  NaN
# 3            NaN                  NaN                  NaN
# 4            NaN                  NaN                  NaN
#
#    z_shot_end_location shot_outcome shot_type
# 0                  NaN          NaN       NaN
# 1                  NaN          NaN       NaN
# 2                  NaN          NaN       NaN
# 3                  NaN          NaN       NaN
# 4                  NaN          NaN       NaN

# %%
df_events.type.value_counts()
# Out:
# Pass              33
# Ball Receipt      19
# Clearance          6
# Duel               3
# Throw-in           3
# Interception       3
# Starting XI        2
# Half Start         2
# Miscontrol         2
# Ball Recovery      2
# Foul Committed     2
# Shot               2
# Goal Keeper        2
# Dribble            1
# Name: type, dtype: int64

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            82 non-null     object
#  1   team                 82 non-null     object
#  2   type                 82 non-null     object
#  3   minute               82 non-null     int64
#  4   x_location           77 non-null     float64
#  5   y_location           77 non-null     float64
#  6   x_pass_end_location  40 non-null     float64
#  7   y_pass_end_location  40 non-null     float64
#  8   pass_recipient       25 non-null     object
#  9   pass_outcome         34 non-null     object
#  10  pass_height          34 non-null     object
#  11  player               76 non-null     object
#  12  possession_team      82 non-null     object
#  13  shot_aerial_won      0 non-null      float64
#  14  shot_body_part       2 non-null      object
#  15  x_shot_end_location  2 non-null      float64
#  16  y_shot_end_location  2 non-null      float64
#  17  z_shot_end_location  2 non-null      float64
#  18  shot_outcome         2 non-null      object
#  19  shot_type            2 non-null      object
# dtypes: float64(8), int64(1), object(11)
# memory usage: 12.9+ KB

# %%
df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')]
# Out:
#        timestamp             team  type  minute  x_location  y_location  \
# 5   00:00:03.332  C.D. Retiro Sur  Pass       0        38.0        32.0
# 7   00:00:07.082  C.D. Retiro Sur  Pass       0        89.0        60.0
# 9   00:00:08.242  C.D. Retiro Sur  Pass       0        84.0        56.0
# 31  00:01:25.890  C.D. Retiro Sur  Pass       1        54.0        59.0
# 33  00:01:27.120  C.D. Retiro Sur  Pass       1        50.0        66.0
# 35  00:01:32.580  C.D. Retiro Sur  Pass       1        56.0        32.0
# 36  00:01:34.330  C.D. Retiro Sur  Pass       1        84.0        62.0
# 37  00:01:36.690  C.D. Retiro Sur  Pass       1        95.0        45.0
# 39  00:01:39.020  C.D. Retiro Sur  Pass       1        91.0        42.0
# 40  00:01:39.620  C.D. Retiro Sur  Pass       1        89.0        38.0
# 52  00:01:55.120  C.D. Retiro Sur  Pass       1        18.0        15.0
# 58  00:02:33.090  C.D. Retiro Sur  Pass       2         7.0        40.0
# 60  00:02:38.240  C.D. Retiro Sur  Pass       2        60.0        57.0
# 63  00:03:07.240  C.D. Retiro Sur  Pass       3        85.0        50.0
# 65  00:03:11.040  C.D. Retiro Sur  Pass       3       106.0        32.0
# 74  00:04:23.330  C.D. Retiro Sur  Pass       4         7.0        33.0
# 76  00:04:28.330  C.D. Retiro Sur  Pass       4        18.0        18.0
#
#     x_pass_end_location  y_pass_end_location  pass_recipient pass_outcome  \
# 5                  89.0                 60.0     Ali Nabahim     Complete
# 7                  84.0                 56.0    Raúl Angullo     Complete
# 9                  94.0                 40.0     Juan Camilo     Complete
# 31                 50.0                 66.0     Ramón Salas     Complete
# 33                 54.0                 35.0    Adrian Lopez     Complete
# 35                 84.0                 62.0  Daniel Serrano     Complete
# 36                 95.0                 48.0     Ali Nabahim     Complete
# 37                 91.0                 42.0    Raúl Angullo     Complete
# 39                 89.0                 38.0     Oscar López     Complete
# 40                102.0                 18.0             NaN   Incomplete
# 52                 37.0                 15.0             NaN   Incomplete
# 58                 60.0                 62.0             NaN   Incomplete
# 60                 75.0                 57.0     Ali Nabahim     Complete
# 63                108.0                 35.0             NaN   Incomplete
# 65                102.0                 40.0    Raúl Angullo     Complete
# 74                  9.0                 20.0    Adrian Lopez     Complete
# 76                 72.0                 19.0             NaN   Incomplete
#
#     pass_height              player  possession_team  shot_aerial_won  \
# 5     High Pass        Adrian Lopez  C.D. Retiro Sur              NaN
# 7      Low Pass         Ali Nabahim  C.D. Retiro Sur              NaN
# 9     High Pass        Raúl Angullo  C.D. Retiro Sur              NaN
# 31  Ground Pass  Guillermo Escalera  C.D. Retiro Sur              NaN
# 33  Ground Pass         Ramón Salas  C.D. Retiro Sur              NaN
# 35    High Pass        Adrian Lopez  C.D. Retiro Sur              NaN
# 36    High Pass      Daniel Serrano  C.D. Retiro Sur              NaN
# 37     Low Pass         Ali Nabahim  C.D. Retiro Sur              NaN
# 39  Ground Pass        Raúl Angullo  C.D. Retiro Sur              NaN
# 40     Low Pass         Oscar López  C.D. Retiro Sur              NaN
# 52  Ground Pass      Francisco José  C.D. Retiro Sur              NaN
# 58    High Pass       Ignacio Salas  C.D. Retiro Sur              NaN
# 60    High Pass        Raúl Angullo  C.D. Retiro Sur              NaN
# 63    High Pass         Oscar López  C.D. Retiro Sur              NaN
# 65  Ground Pass  Sebastian Olivares  C.D. Retiro Sur              NaN
# 74  Ground Pass       Ignacio Salas  C.D. Retiro Sur              NaN
# 76    High Pass        Adrian Lopez  C.D. Retiro Sur              NaN
#
#    shot_body_part  x_shot_end_location  y_shot_end_location  \
# 5             NaN                  NaN                  NaN
# 7             NaN                  NaN                  NaN
# 9             NaN                  NaN                  NaN
# 31            NaN                  NaN                  NaN
# 33            NaN                  NaN                  NaN
# 35            NaN                  NaN                  NaN
# 36            NaN                  NaN                  NaN
# 37            NaN                  NaN                  NaN
# 39            NaN                  NaN                  NaN
# 40            NaN                  NaN                  NaN
# 52            NaN                  NaN                  NaN
# 58            NaN                  NaN                  NaN
# 60            NaN                  NaN                  NaN
# 63            NaN                  NaN                  NaN
# 65            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 76            NaN                  NaN                  NaN
#
#     z_shot_end_location shot_outcome shot_type
# 5                   NaN          NaN       NaN
# 7                   NaN          NaN       NaN
# 9                   NaN          NaN       NaN
# 31                  NaN          NaN       NaN
# 33                  NaN          NaN       NaN
# 35                  NaN          NaN       NaN
# 36                  NaN          NaN       NaN
# 37                  NaN          NaN       NaN
# 39                  NaN          NaN       NaN
# 40                  NaN          NaN       NaN
# 52                  NaN          NaN       NaN
# 58                  NaN          NaN       NaN
# 60                  NaN          NaN       NaN
# 63                  NaN          NaN       NaN
# 65                  NaN          NaN       NaN
# 74                  NaN          NaN       NaN
# 76                  NaN          NaN       NaN

# %%
df_events[(df_events.type == 'Shot')& (df_events.shot_outcome == 'Goal')]
# Out:
#        timestamp             team  type  minute  x_location  y_location  \
# 66  00:03:12.340  C.D. Retiro Sur  Shot       3       102.0        40.0
#
#     x_pass_end_location  y_pass_end_location pass_recipient pass_outcome  \
# 66                  NaN                  NaN            NaN          NaN
#
#    pass_height        player  possession_team  shot_aerial_won shot_body_part  \
# 66         NaN  Raúl Angullo  C.D. Retiro Sur              NaN      Left Foot
#
#     x_shot_end_location  y_shot_end_location  z_shot_end_location  \
# 66                120.0                 37.0                  3.0
#
#    shot_outcome  shot_type
# 66         Goal  Open Play

# %%
pitch = mls.Pitch(pitch_type='statsbomb',pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(14, 7), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

## Pases Completatos del Retiro
pitch.arrows(df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass') & (df_events.pass_outcome == 'Complete')].x_location, df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Complete')].y_location,
             df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Complete')].x_pass_end_location, df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Complete')].y_pass_end_location, width=2,
             headwidth=5, headlength=7, headaxislength=12, color='#ad993c', ax=ax, label='Pases completados')

## Pases Fallados del Retiro
pitch.arrows(df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass') & (df_events.pass_outcome == 'Incomplete')].x_location, df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Incomplete')].y_location,
             df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Incomplete')].x_pass_end_location, df_events[(df_events.team == 'C.D. Retiro Sur') & (df_events.type == 'Pass')& (df_events.pass_outcome == 'Incomplete')].y_pass_end_location, width=2,
             headwidth=5, headlength=7, headaxislength=12,
             color='#ba4f45', ax=ax, label='Pases incompletos')
## Leyenda
ax.legend(facecolor='#22312b', handlelength=2, edgecolor='None', fontsize=15, loc='upper left')

## Titulo
ax_title = ax.set_title('Pases completados vs Pases incompletos', fontsize=25)

# %%
pitch = mls.Pitch(pitch_type='statsbomb',pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(14, 7), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

## Pases Completatos del Retiro
pitch.arrows(df_events[(df_events.type == 'Shot')& (df_events.shot_outcome == 'Goal')].x_location, df_events[(df_events.type == 'Shot')& (df_events.shot_outcome == 'Goal')].y_location,
             df_events[(df_events.type == 'Shot')& (df_events.shot_outcome == 'Goal')].x_shot_end_location, df_events[(df_events.type == 'Shot')& (df_events.shot_outcome == 'Goal')].y_shot_end_location, width=2,
             headwidth=5, headlength=7, headaxislength=12, color='#27FF00', ax=ax, label='Gol')

## Pases Fallados del Retiro
pitch.arrows(df_events[(df_events.type == 'Shot')& (df_events.shot_outcome != 'Goal')].x_location, df_events[(df_events.type == 'Shot')& (df_events.shot_outcome != 'Goal')].y_location,
             df_events[(df_events.type == 'Shot')& (df_events.shot_outcome != 'Goal')].x_shot_end_location, df_events[(df_events.type == 'Shot')& (df_events.shot_outcome != 'Goal')].y_shot_end_location, width=2,
             headwidth=5, headlength=7, headaxislength=12,
             color='#ba4f45', ax=ax, label='Tiros Fallidos')
## Leyenda
ax.legend(facecolor='#22312b', handlelength=2, edgecolor='None', fontsize=15, loc='upper left')

## Titulo
ax_title = ax.set_title('Goles vs Tiros Fallidos', fontsize=25)

# %%
flamingo_cmap = plt.colors.LinearSegmentedColormap.from_list("Flamingo - 100 colors",
                                                  ['#e3aca7', '#c03a1d'], N=100)

# %%
# Mapa de calor del equipo
pitch = mls.VerticalPitch(line_color='#000009', line_zorder=2)
fig, ax = pitch.draw(figsize=(4.4, 6.4))

kde = pitch.kdeplot(df_events[df_events.team == 'C.D. Retiro Sur'].x_location, df_events[df_events.team == 'C.D. Retiro Sur'].y_location, ax=ax,
                    # shade using 100 levels so it looks smooth
                    shade=True, levels=100,
                    # shade the lowest area so it looks smooth
                    # so even if there are no events it gets some color
                    shade_lowest=True,
                    cut=4,  # extended the cut so it reaches the bottom edge
                    cmap=flamingo_cmap)
