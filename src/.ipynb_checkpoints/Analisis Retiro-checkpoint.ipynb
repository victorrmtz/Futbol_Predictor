# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df_lineups = pd.read_excel('../lineups.xlsx', sheet_name='Hoja1')
df_lineups.head()
# Out:
#    id  jersey_number     player_name             team country time_card  \
# 0   0              1   Ignacio Salas  C.D. Retiro Sur   Spain       NaN
# 1   1              3  Manuel Pascual  C.D. Retiro Sur   Spain       NaN
# 2   2              5    Adrian Lopez  C.D. Retiro Sur   Spain     89:00
# 3   3              6  Francisco José  C.D. Retiro Sur   Spain       NaN
# 4   4              7     Juan Camilo  C.D. Retiro Sur   Spain     67:00
#
#   card_type          reason  period  position_id position   from     to  \
# 0       NaN             NaN     NaN            1      POR  00:00    NaN
# 1       NaN             NaN     NaN            2       LD    NaN    NaN
# 2    Yellow  Falta cometida     2.0            3       CB  00:00    NaN
# 3       NaN             NaN     NaN            4       LI  00:00    NaN
# 4    Yellow  Falta cometida     2.0            5       DC  00:00  84:00
#
#    from_period  to_period start_reason end_reason
# 0          1.0        NaN           XI      Final
# 1          NaN        NaN          NaN        NaN
# 2          1.0        NaN           XI      Final
# 3          1.0        NaN           XI      Final
# 4          1.0        2.0           XI    Táctico
