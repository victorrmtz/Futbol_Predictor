# %%
from statsbombpy import sb
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df_competitions = sb.competitions()
df_competitions.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2022-08-14T16:57:15.866765  2021-06-13T16:17:31.694
# ...

# %%
df_competitions[df_competitions.country_name == 'Spain']
# Out:
#     competition_id  season_id country_name competition_name  \
# 20              11         90        Spain          La Liga
# 21              11         42        Spain          La Liga
# 22              11          4        Spain          La Liga
# 23              11          1        Spain          La Liga
# 24              11          2        Spain          La Liga
# 25              11         27        Spain          La Liga
# 26              11         26        Spain          La Liga
# 27              11         25        Spain          La Liga
# 28              11         24        Spain          La Liga
# 29              11         23        Spain          La Liga
# 30              11         22        Spain          La Liga
# 31              11         21        Spain          La Liga
# 32              11         41        Spain          La Liga
# 33              11         40        Spain          La Liga
# 34              11         39        Spain          La Liga
# ...

# %%
df_2020 = sb.matches(competition_id=11, season_id=90)
df_2020.head()
# Out:
#    match_id  match_date      kick_off      competition     season  \
# 0   3773631  2021-02-07  21:00:00.000  Spain - La Liga  2020/2021
# 1   3773665  2021-03-06  21:00:00.000  Spain - La Liga  2020/2021
# 2   3773497  2021-04-10  21:00:00.000  Spain - La Liga  2020/2021
# 3   3773660  2020-12-13  21:00:00.000  Spain - La Liga  2020/2021
# 4   3773593  2020-09-27  21:00:00.000  Spain - La Liga  2020/2021
#
#      home_team   away_team  home_score  away_score match_status  \
# 0   Real Betis   Barcelona           2           3    available
# 1      Osasuna   Barcelona           0           2    available
# 2  Real Madrid   Barcelona           2           1    available
# 3    Barcelona     Levante           1           0    available
# 4    Barcelona  Villarreal           4           0    available
#
#   match_status_360                last_updated  last_updated_360  match_week  \
# 0        available  2021-02-24T16:46:37.954522  2022-08-04T12:00          22
# ...

# %%
id_clasico = 3773497
df_2020[df_2020['match_id'] == id_clasico]
# Out:
#    match_id  match_date      kick_off      competition     season  \
# 2   3773497  2021-04-10  21:00:00.000  Spain - La Liga  2020/2021
#
#      home_team  away_team  home_score  away_score match_status  \
# 2  Real Madrid  Barcelona           2           1    available
#
#   match_status_360                last_updated  last_updated_360  match_week  \
# 2        available  2021-04-25T19:46:09.138046  2022-08-04T12:00          30
#
#   competition_stage                     stadium            referee  \
# 2    Regular Season  Estadio Alfredo Di Stéfano  Jesús Gil Manzano
#
#      home_managers  away_managers data_version shot_fidelity_version  \
# 2  Zinédine Zidane  Ronald Koeman        1.1.0                     2
#
#   xy_fidelity_version
# 2                   2

# %%
df_lineups = sb.lineups(match_id = id_clasico)
df_lineups.keys()
# Out:
# dict_keys(['Real Madrid', 'Barcelona'])

# %%
df_lineups['Real Madrid']
# Out:
#     player_id                              player_name    player_nickname  \
# 0        3163                       Mariano Díaz Mejía       Mariano Díaz
# 1        3509                         Thibaut Courtois               None
# 2        3804                            Ferland Mendy               None
# 3        4926           Francisco Román Alarcón Suárez               Isco
# 4        5200                   Lucas Vázquez Iglesias      Lucas Vázquez
# 5        5202          José Ignacio Fernández Iglesias              Nacho
# 6        5463                              Luka Modrić               None
# 7        5539                 Carlos Henrique Casimiro           Casemiro
# 8        5552           Marcelo Vieira da Silva Júnior            Marcelo
# 9        5574                               Toni Kroos               None
# 10       5719                  Marco Asensio Willemsen               None
# 11       6689                Álvaro Odriozola Arzallus   Álvaro Odriozola
# ...

# %%
df_lineups['Real Madrid'].cards[7]
# Out:
# [{'time': '88:24',
#   'card_type': 'Yellow Card',
#   'reason': 'Foul Committed',
#   'period': 2},
#  {'time': '89:23',
#   'card_type': 'Second Yellow',
#   'reason': 'Foul Committed',
#   'period': 2}]

# %%
df_events = sb.events(match_id = id_clasico)
df_events.head()
# Out:
#   bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0                NaN                  NaN                     NaN
# 1                NaN                  NaN                     NaN
# 2                NaN                  NaN                     NaN
# 3                NaN                  NaN                     NaN
# 4                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0                NaN                  NaN                 NaN            NaN
# ...

# %%
df_events.columns
# Out:
# Index(['bad_behaviour_card', 'ball_receipt_outcome', 'ball_recovery_offensive',
#        'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'miscontrol_aerial_won', 'off_camera', 'out', 'pass_aerial_won',
# ...

# %%
df_events = df_events[['timestamp','team', 'type', 'minute', 'location', 'pass_end_location','pass_recipient', 'pass_outcome',
                       'pass_height','player','possession_team', 'shot_aerial_won', 'shot_body_part', 'shot_end_location', 
                       'shot_outcome', 'shot_type']]
df_events = df_events.sort_values(['minute', 'timestamp'])

# %%
df_events.head(30)
# Out:
#          timestamp         team           type  minute      location  \
# 0     00:00:00.000  Real Madrid    Starting XI       0           NaN
# 1     00:00:00.000    Barcelona    Starting XI       0           NaN
# 2     00:00:00.000    Barcelona     Half Start       0           NaN
# 3     00:00:00.000  Real Madrid     Half Start       0           NaN
# 1674  00:00:00.253    Barcelona  Ball Receipt*       0  [92.6, 52.9]
# 6     00:00:00.687    Barcelona           Pass       0  [61.0, 40.1]
# 1109  00:00:01.544    Barcelona  Ball Receipt*       0  [50.4, 44.6]
# 2152  00:00:01.544    Barcelona          Carry       0  [50.4, 44.6]
# 7     00:00:03.779    Barcelona           Pass       0  [51.8, 42.7]
# 1110  00:00:05.175    Barcelona  Ball Receipt*       0  [43.9, 28.0]
# 2153  00:00:05.175    Barcelona          Carry       0  [43.9, 28.0]
# 8     00:00:06.165    Barcelona           Pass       0  [43.0, 26.8]
# 1111  00:00:06.735    Barcelona  Ball Receipt*       0  [53.4, 28.6]
# ...

# %%
df_events[df_events.type == 'Shot']
# Out:
#          timestamp         team  type  minute       location  \
# 3940  00:09:14.816    Barcelona  Shot       9  [101.9, 58.1]
# 3941  00:12:58.955  Real Madrid  Shot      12  [113.8, 45.4]
# 3942  00:15:28.083    Barcelona  Shot      15  [116.1, 38.6]
# 3943  00:20:16.021  Real Madrid  Shot      20  [103.1, 35.5]
# 3944  00:23:11.513  Real Madrid  Shot      23   [90.9, 34.5]
# 3945  00:27:06.449  Real Madrid  Shot      27  [101.0, 27.2]
# 3946  00:33:49.727  Real Madrid  Shot      33  [107.3, 53.4]
# 3947  00:33:51.417  Real Madrid  Shot      33  [105.9, 42.4]
# 3948  00:34:36.417  Real Madrid  Shot      34   [96.2, 47.9]
# 3949  00:34:37.931  Real Madrid  Shot      34  [108.6, 41.4]
# 3950  00:36:07.631    Barcelona  Shot      36   [94.9, 46.8]
# 3951  00:40:42.624    Barcelona  Shot      40   [99.8, 33.8]
# 3952  00:44:50.325    Barcelona  Shot      44  [112.8, 24.6]
# 3954  00:02:24.662    Barcelona  Shot      47  [114.1, 32.7]
# ...

# %%
df_events.type.unique()
# Out:
# array(['Starting XI', 'Half Start', 'Ball Receipt*', 'Pass', 'Carry',
#        'Pressure', 'Ball Recovery', 'Interception', 'Dribbled Past',
#        'Dribble', 'Foul Committed', 'Foul Won', 'Dispossessed', 'Duel',
#        'Miscontrol', 'Block', 'Clearance', 'Goal Keeper', 'Shot',
#        'Injury Stoppage', 'Substitution', 'Half End', 'Tactical Shift',
#        'Bad Behaviour'], dtype=object)

# %%
df_events.pass_height.unique()
# Out:
# array([nan, 'Ground Pass', 'High Pass', 'Low Pass'], dtype=object)

# %%
df_events.pass_outcome.unique()
# Out:
# array([nan, 'Incomplete', 'Out', 'Unknown', 'Injury Clearance',
#        'Pass Offside'], dtype=object)

# %%
df_events.shape
# Out:
# (3991, 16)

# %%
even = pd.read_csv('eventos.csv')
even.head()
# Out:
#    match_id  match_run_time_in_ms match_run_time  match_time_in_ms  event_id  \
# 0    128074                     0       00:00:00                 0         1
# 1    128074                     0       00:00:00                 0         2
# 2    128074                  1519       00:00:01              1519         3
# 3    128074                  1590       00:00:01              1590         4
# 4    128074                  1590       00:00:01              1590         5
#
#    player_seq_id  event_order  half_time side       category  \
# 0              1            1          1    l  in_possession
# 1              1            2          1    l  in_possession
# 2              1            3          1    l  in_possession
# 3              2            1          1    l  in_possession
# 4              2            2          1    l  in_possession
#
#                 event            event_type action_type  from_player_id  \
# ...

# %%
even.x.min()
# Out:
# -0.001
